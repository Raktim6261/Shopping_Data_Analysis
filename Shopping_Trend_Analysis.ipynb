# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
shop=pd.read_csv("shopping_trends.csv")

# %%
print(shop)
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 0               1   55    Male         Blouse     Clothing
# 1               2   19    Male        Sweater     Clothing
# 2               3   50    Male          Jeans     Clothing
# 3               4   21    Male        Sandals     Footwear
# 4               5   45    Male         Blouse     Clothing
# ...           ...  ...     ...            ...          ...
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (USD)       Location Size      Color  Season  \
# 0                        53       Kentucky    L       Gray  Winter
# 1                        64          Maine    L     Maroon  Winter
# ...

# %%
shop.head()
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse  Clothing                     53
# 1            2   19   Male        Sweater  Clothing                     64
# 2            3   50   Male          Jeans  Clothing                     73
# 3            4   21   Male        Sandals  Footwear                     90
# 4            5   45   Male         Blouse  Clothing                     49
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
# ...

# %%
shop.isna().sum()
# Out:
# Customer ID                 0
# Age                         0
# Gender                      0
# Item Purchased              0
# Category                    0
# Purchase Amount (USD)       0
# Location                    0
# Size                        0
# Color                       0
# Season                      0
# Review Rating               0
# Subscription Status         0
# Payment Method              0
# Shipping Type               0
# Discount Applied            0
# Promo Code Used             0
# Previous Purchases          0
# Preferred Payment Method    0
# Frequency of Purchases      0
# dtype: int64

# %%
shop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Customer ID               3900 non-null   int64
#  1   Age                       3900 non-null   int64
#  2   Gender                    3900 non-null   object
#  3   Item Purchased            3900 non-null   object
#  4   Category                  3900 non-null   object
#  5   Purchase Amount (USD)     3900 non-null   int64
#  6   Location                  3900 non-null   object
#  7   Size                      3900 non-null   object
#  8   Color                     3900 non-null   object
#  9   Season                    3900 non-null   object
#  10  Review Rating             3900 non-null   float64
#  11  Subscription Status       3900 non-null   object
#  12  Payment Method            3900 non-null   object
# ...

# %%
shop.describe()
# Out:
#        Customer ID          Age  Purchase Amount (USD)  Review Rating  \
# count  3900.000000  3900.000000            3900.000000    3900.000000
# mean   1950.500000    44.068462              59.764359       3.749949
# std    1125.977353    15.207589              23.685392       0.716223
# min       1.000000    18.000000              20.000000       2.500000
# 25%     975.750000    31.000000              39.000000       3.100000
# 50%    1950.500000    44.000000              60.000000       3.700000
# 75%    2925.250000    57.000000              81.000000       4.400000
# max    3900.000000    70.000000             100.000000       5.000000
#
#        Previous Purchases
# count         3900.000000
# mean            25.351538
# std             14.447125
# min              1.000000
# 25%             13.000000
# 50%             25.000000
# 75%             38.000000
# max             50.000000

# %%
shop.duplicated().sum()
# Out:
# np.int64(0)

# %%
shop["Age"].plot(kind="hist")
plt.title("Histogram of Age")
plt.ylabel("Frequency")
plt.xlabel("Age")
plt.show()

# %%
shop.columns
# Out:
# Index(['Customer ID', 'Age', 'Gender', 'Item Purchased', 'Category',
#        'Purchase Amount (USD)', 'Location', 'Size', 'Color', 'Season',
#        'Review Rating', 'Subscription Status', 'Payment Method',
#        'Shipping Type', 'Discount Applied', 'Promo Code Used',
#        'Previous Purchases', 'Preferred Payment Method',
#        'Frequency of Purchases'],
#       dtype='object')

# %%
shop["Gender"].value_counts().plot(kind="bar")
plt.title("Bar plot for Gender Distribution")
plt.xlabel("Gender")
plt.ylabel("Count")
plt.show()

# %%
shop.groupby("Category")["Purchase Amount (USD)"].mean().sort_values(ascending=False).head()
# Out:
# Category
# Footwear       60.255426
# Clothing       60.025331
# Accessories    59.838710
# Outerwear      57.172840
# Name: Purchase Amount (USD), dtype: float64

# %%
shop.sort_values("Review Rating",ascending=False,inplace=True)

# %%
shop["Subscription Status"].value_counts().plot(kind="pie")
plt.title("Pie Chart for Subscription")
plt.show()

# %%
shop["Color"].value_counts().head()
# Out:
# Color
# Olive     177
# Yellow    174
# Silver    173
# Teal      172
# Green     169
# Name: count, dtype: int64

# %%
shop["Color"].value_counts().head().plot(kind="pie")
plt.show()

# %%
shop.head(15).plot(x="Previous Purchases",y="Review Rating", kind="scatter")
plt.title("Scatter plot -previous purchases review rating")
plt.show()

# %%
shop.groupby("Season")["Purchase Amount (USD)"].sum()
# Out:
# Season
# Fall      60018
# Spring    58679
# Summer    55777
# Winter    58607
# Name: Purchase Amount (USD), dtype: int64

# %%
shop.boxplot(column="Purchase Amount (USD)",by="Frequency of Purchases")
plt.title("Box plot of Amount based on frequency of purchase")
plt.show()

# %%
shop["Preferred Payment Method"].value_counts().max()
# Out:
# np.int64(677)

# %%
pd.pivot_table(data=shop,values="Purchase Amount (USD)",index="Location",columns="Item Purchased",aggfunc="mean")
# Out:
# Item Purchased   Backpack       Belt     Blouse      Boots       Coat  \
# Location
# Alabama         74.000000  26.500000  52.000000  73.666667  54.500000
# Alaska          74.600000  76.750000  67.500000  56.000000  45.500000
# Arizona         48.600000  84.500000  61.000000        NaN  65.333333
# Arkansas        90.000000  55.000000  66.000000  50.000000  54.250000
# California      57.400000  61.666667  39.500000  62.500000  55.000000
# Colorado        57.000000  68.500000  55.000000        NaN  46.000000
# Connecticut     60.000000  47.666667  67.400000  64.250000  44.500000
# Delaware        33.000000  41.500000  42.200000  44.500000  57.500000
# Florida         59.000000  94.000000  31.000000  51.500000  51.166667
# Georgia         44.750000  62.000000  64.857143  85.000000  93.000000
# Hawaii          96.000000  44.000000  50.600000  74.000000  69.666667
# Idaho           53.250000  61.000000  65.000000  60.333333  65.250000
# ...

# %%
shop.groupby("Size")["Purchase Amount (USD)"].mean()
# Out:
# Size
# L     58.563153
# M     59.924217
# S     61.037707
# XL    60.090909
# Name: Purchase Amount (USD), dtype: float64

# %%
shop.groupby("Payment Method")["Purchase Amount (USD)"].sum()
# Out:
# Payment Method
# Bank Transfer    37123
# Cash             38833
# Credit Card      42567
# Debit Card       37118
# PayPal           37449
# Venmo            39991
# Name: Purchase Amount (USD), dtype: int64

# %%
shop.groupby("Discount Applied")["Review Rating"].mean()
# Out:
# Discount Applied
# No     3.757715
# Yes    3.739654
# Name: Review Rating, dtype: float64

# %%
shop.groupby("Color")["Category"].value_counts()
# Out:
# Color   Category
# Beige   Clothing       65
#         Accessories    44
#         Footwear       24
#         Outerwear      14
# Black   Clothing       81
#                        ..
# White   Outerwear      15
# Yellow  Clothing       75
#         Accessories    56
#         Footwear       30
#         Outerwear      13
# Name: count, Length: 100, dtype: int64

# %%
shop.groupby("Frequency of Purchases")["Previous Purchases"].median()
# Out:
# Frequency of Purchases
# Annually          24.0
# Bi-Weekly         24.0
# Every 3 Months    24.0
# Fortnightly       26.0
# Monthly           25.0
# Quarterly         28.0
# Weekly            26.0
# Name: Previous Purchases, dtype: float64

# %%
shop.groupby("Season")["Review Rating"].mean()
# Out:
# Season
# Fall      3.729949
# Spring    3.790591
# Summer    3.725654
# Winter    3.752111
# Name: Review Rating, dtype: float64

# %%
shop["Season"].value_counts().plot(kind="bar")
plt.xlabel("Season")
plt.ylabel("Count")
plt.title("Amount of Purchases in Each Season")
plt.show()

# %%
shop["Category"].value_counts().plot(kind="pie")
plt.show()

# %%
shop.boxplot(column="Review Rating", by="Gender")
plt.title("Review Rating Distribution by Gender")
plt.show()

# %%
shop["Purchase Amount (USD)"].plot(kind="hist",bins=10)
plt.xlabel("USD")
plt.ylabel("Frequency")
plt.title("Histogram of Purchase Amount Distribution")
plt.show()

# %%
shop.groupby("Color")["Review Rating"].mean().head().plot(kind="bar")
plt.xlabel("Color")
plt.ylabel("Mean Review Rating")
plt.title("Mean Review Rating for Each Color")
plt.show()

# %%
shop.groupby("Payment Method")["Purchase Amount (USD)"].sum().plot(kind="pie")
plt.title("Sum of Purchases Amount by Payment Method")

plt.ylabel("")
plt.show()

# %%
shop.boxplot(column="Purchase Amount (USD)",by="Frequency of Purchases")
plt.xlabel("Frequency of Purchases")
plt.ylabel("Purchase Amount (USD)")
plt.title("Purchase Amount Distribution by Frequency of Purchases")
plt.show()

# %%
shop.groupby("Season")["Purchase Amount (USD)"].sum().plot(kind="pie")
plt.xlabel("Season")
plt.ylabel("Sum of Purchase Amount (USD)")
plt.title("Sum of Purchase Amount by Season")
plt.show()
